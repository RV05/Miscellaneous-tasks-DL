# %% [markdown]
# <a href="https://colab.research.google.com/github/RV05/Miscellaneous-tasks-DL/blob/main/Copy_of_Burn_skin_inception_20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/deep learning
# Out:
# /content/drive/MyDrive/deep learning

# %%
import matplotlib
matplotlib.use("Agg")
# import the necessary packages
import config
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.applications import EfficientNetB7
from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications import VGG19

from tensorflow.keras.optimizers import Adagrad
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import GlobalAveragePooling2D

from sklearn.metrics import classification_report
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import argparse
# ap = argparse.ArgumentParser()
# ap.add_argument("-p", "--plot", type=str, default="plot.png",
# 	help="path to output loss/accuracy plot")
# args = vars(ap.parse_args())
# # determine the total number of image paths in training, validation,
# # and testing directories

# %%
totalTrain = len(list(paths.list_images(config.TRAIN_PATH)))
totalVal = len(list(paths.list_images(config.VAL_PATH)))
totalTest = len(list(paths.list_images(config.TEST_PATH)))
trainAug = ImageDataGenerator(
	rotation_range=25,
	zoom_range=0.1,
	width_shift_range=0.1,
	height_shift_range=0.1,
	shear_range=0.2,
	horizontal_flip=True,
	fill_mode="nearest")

# %%
# initialize the validation/testing data augmentation object (which
# we'll be adding mean subtraction to)
valAug = ImageDataGenerator()

# %%
# define the ImageNet mean subtraction (in RGB order) and set the
# the mean subtraction value for each of the data augmentation
# objects
mean = np.array([123.68, 116.779, 103.939], dtype="float32")
trainAug.mean = mean
valAug.mean = mean

# %%
trainGen = trainAug.flow_from_directory(
	config.TRAIN_PATH,
	class_mode="categorical",
	target_size=(200, 200),
	color_mode="rgb",
	shuffle=True,
	batch_size=config.BS)
# initialize the validation generator
valGen = valAug.flow_from_directory(
	config.VAL_PATH,
	class_mode="categorical",
	target_size=(200, 200),
	color_mode="rgb",
	shuffle=False,
	batch_size=config.BS)
# initialize the testing generator
testGen = valAug.flow_from_directory(
	config.TEST_PATH,
	class_mode="categorical",
	target_size=(200, 200),
	color_mode="rgb",
	shuffle=False,
	batch_size=config.BS)
# Out:
# Found 174 images belonging to 4 classes.
# Found 19 images belonging to 4 classes.
# Found 65 images belonging to 4 classes.

# %%
print("[INFO] preparing model...")
baseModel = EfficientNetB7(weights="imagenet", include_top=False,
	input_tensor=Input(shape=(200, 200, 3)))
# construct the head of the model that will be placed on top of the
# the base model
headModel = baseModel.output
headModel = AveragePooling2D()(headModel)
headModel = Flatten(name="flatten")(headModel)
headModel = Dense(256, activation="relu")(headModel)
headModel = Dense(256, activation="relu")(headModel)
headModel = Dense(256, activation="relu")(headModel)
headModel = Dense(256, activation="relu")(headModel)
headModel = Dense(256, activation="relu")(headModel)

headModel = Dropout(0.5)(headModel)

headModel = Dense(len(config.CLASSES), activation="softmax")(headModel)
# place the head FC model on top of the base model (this will become
# the actual model we will train)
model = Model(inputs=baseModel.input, outputs=headModel)
# loop over all layers in the base model and freeze them so they will
# *not* be updated during the training process
for layer in baseModel.layers:
	layer.trainable = False
# compile the model
opt = Adam(lr=config.INIT_LR, decay=config.INIT_LR / config.NUM_EPOCHS)
model.compile(loss="categorical_crossentropy", optimizer=opt,
	metrics=["accuracy"])
# train the model
# Out:
# [INFO] preparing model...
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb7_notop.h5
# 258080768/258076736 [==============================] - 2s 0us/step
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
# load the ResNet-50 network, ensuring the head FC layer sets are left
# off

print("[INFO] training model...")
H = model.fit_generator(
	trainGen,
	steps_per_epoch=totalTrain // config.BS,
	validation_data=valGen,
	validation_steps=totalVal // config.BS,
	epochs=config.NUM_EPOCHS)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1940: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# [INFO] training model...
# Epoch 1/200
# 21/21 [==============================] - 84s 2s/step - loss: 1.3816 - accuracy: 0.2831 - val_loss: 1.2481 - val_accuracy: 0.6250
# Epoch 2/200
# 21/21 [==============================] - 3s 139ms/step - loss: 1.1259 - accuracy: 0.5542 - val_loss: 0.8866 - val_accuracy: 0.7500
# Epoch 3/200
# 21/21 [==============================] - 3s 136ms/step - loss: 0.7728 - accuracy: 0.7410 - val_loss: 0.5838 - val_accuracy: 0.9375
# Epoch 4/200
# 21/21 [==============================] - 3s 137ms/step - loss: 0.5630 - accuracy: 0.7831 - val_loss: 0.4929 - val_accuracy: 0.9375
# Epoch 5/200
# 21/21 [==============================] - 3s 139ms/step - loss: 0.4002 - accuracy: 0.8929 - val_loss: 0.5469 - val_accuracy: 0.8750
# Epoch 6/200
# 21/21 [==============================] - 3s 138ms/step - loss: 0.3581 - accuracy: 0.8735 - val_loss: 0.5424 - val_accuracy: 0.8750
# Epoch 7/200
# 21/21 [==============================] - 3s 138ms/step - loss: 0.2024 - accuracy: 0.9277 - val_loss: 0.6021 - val_accuracy: 0.8750
# Epoch 8/200
# 21/21 [==============================] - 3s 136ms/step - loss: 0.1838 - accuracy: 0.9578 - val_loss: 0.5903 - val_accuracy: 0.8750
# Epoch 9/200
# 21/21 [==============================] - 3s 137ms/step - loss: 0.1567 - accuracy: 0.9578 - val_loss: 0.5524 - val_accuracy: 0.7500
# Epoch 10/200
# 21/21 [==============================] - 3s 138ms/step - loss: 0.1045 - accuracy: 0.9699 - val_loss: 0.6204 - val_accuracy: 0.9375
# Epoch 11/200
# 21/21 [==============================] - 3s 133ms/step - loss: 0.0892 - accuracy: 0.9819 - val_loss: 0.6100 - val_accuracy: 0.8750
# Epoch 12/200
# 21/21 [==============================] - 3s 131ms/step - loss: 0.0303 - accuracy: 1.0000 - val_loss: 0.7532 - val_accuracy: 0.8750
# Epoch 13/200
# 21/21 [==============================] - 3s 129ms/step - loss: 0.0336 - accuracy: 0.9940 - val_loss: 0.6366 - val_accuracy: 0.8750
# Epoch 14/200
# 21/21 [==============================] - 3s 134ms/step - loss: 0.0335 - accuracy: 0.9880 - val_loss: 0.6694 - val_accuracy: 0.8750
# Epoch 15/200
# 21/21 [==============================] - 3s 131ms/step - loss: 0.0251 - accuracy: 0.9940 - val_loss: 0.7074 - val_accuracy: 0.8750
ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 1.1417 - val_accuracy: 0.8750
# Epoch 61/200
# 21/21 [==============================] - 3s 137ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.9090 - val_accuracy: 0.8750
# Epoch 62/200
# 21/21 [==============================] - 3s 134ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.8841 - val_accuracy: 0.8750
# Epoch 63/200
# 21/21 [==============================] - 3s 133ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.9409 - val_accuracy: 0.8125
# Epoch 64/200
# 21/21 [==============================] - 3s 131ms/step - loss: 6.9344e-04 - accuracy: 1.0000 - val_loss: 1.0132 - val_accuracy: 0.8750
# Epoch 65/200
# 21/21 [==============================] - 3s 132ms/step - loss: 8.6478e-04 - accuracy: 1.0000 - val_loss: 1.0270 - val_accuracy: 0.8750
# Epoch 66/200
# 21/21 [==============================] - 3s 135ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.0115 - val_accuracy: 0.8750
# Epoch 67/200
# 21/21 [==============================] - 3s 129ms/step - loss: 6.4771e-04 - accuracy: 1.0000 - val_loss: 1.0113 - val_accuracy: 0.8750
# Epoch 68/200
# 21/21 [==============================] - 3s 131ms/step - loss: 2.6758e-04 - accuracy: 1.0000 - val_loss: 1.0104 - val_accuracy: 0.8750
# Epoch 69/200
# 21/21 [==============================] - 3s 133ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 1.1492 - val_accuracy: 0.8125
# Epoch 70/200
# 21/21 [==============================] - 3s 131ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 1.2337 - val_accuracy: 0.8125
# Epoch 71/200
# 21/21 [==============================] - 3s 132ms/step - loss: 0.0064 - accuracy: 0.9940 - val_loss: 0.9116 - val_accuracy: 0.8750
# Epoch 72/200
# 21/21 [==============================] - 3s 136ms/step - loss: 0.0050 - accuracy: 0.9940 - val_loss: 0.6533 - val_accuracy: 0.8750
# Epoch 73/200
# 21/21 [==============================] - 3s 139ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.7378 - val_accuracy: 0.8750
# Epoch 74/200
# 21/21 [==============================] - 3s 134ms/step - loss: 0.0101 - accuracy: 0.9940 - val_loss: 0.7421 - val_accuracy: 0.8750
# Epoch 75/200
# 21/21 [==============================] - 3s 131ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.7652 - val_accuracy: 0.8750
# Epoch 76/200
# 21/21 [==============================] - 3s 135ms/step - loss: 0.0333 - accuracy: 0.9880 - val_loss: 1.0394 - val_accuracy: 0.8125
# Epoch 77/200
# 21/21 [==============================] - 3s 131ms/step - loss: 0.0585 - accuracy: 0.9880 - val_loss: 1.3370 - val_accuracy: 0.7500
# Epoch 78/200
# 21/21 [==============================] - 3s 133ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.9527 - val_accuracy: 0.8125
# Epoch 79/200
# 21/21 [==============================] - 3s 131ms/step - loss: 0.0157 - accuracy: 0.9880 - val_loss: 0.9790 - val_accuracy: 0.8125
# Epoch 80/200
# 21/21 [==============================] - 3s 132ms/step - loss: 0.0222 - accuracy: 0.9940 - val_loss: 1.0483 - val_accuracy: 0.8125
# Epoch 81/200
# 21/21 [==============================] - 3s 132ms/step - loss: 0.0330 - accuracy: 0.9880 - val_loss: 1.3513 - val_accuracy: 0.8125
# Epoch 82/200
ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.0527 - val_accuracy: 0.8125
# Epoch 126/200
# 21/21 [==============================] - 3s 134ms/step - loss: 8.7329e-04 - accuracy: 1.0000 - val_loss: 1.1726 - val_accuracy: 0.8125
# Epoch 127/200
# 21/21 [==============================] - 3s 139ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.2230 - val_accuracy: 0.8125
# Epoch 128/200
# 21/21 [==============================] - 3s 132ms/step - loss: 1.7600e-04 - accuracy: 1.0000 - val_loss: 1.2306 - val_accuracy: 0.8125
# Epoch 129/200
# 21/21 [==============================] - 3s 132ms/step - loss: 3.8988e-04 - accuracy: 1.0000 - val_loss: 1.2267 - val_accuracy: 0.8125
# Epoch 130/200
# 21/21 [==============================] - 3s 130ms/step - loss: 1.1807e-04 - accuracy: 1.0000 - val_loss: 1.2252 - val_accuracy: 0.8125
# Epoch 131/200
# 21/21 [==============================] - 3s 130ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 1.2084 - val_accuracy: 0.8125
# Epoch 132/200
# 21/21 [==============================] - 3s 130ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.1759 - val_accuracy: 0.8125
# Epoch 133/200
# 21/21 [==============================] - 3s 129ms/step - loss: 5.3200e-04 - accuracy: 1.0000 - val_loss: 1.1247 - val_accuracy: 0.8125
# Epoch 134/200
# 21/21 [==============================] - 3s 132ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.2073 - val_accuracy: 0.8125
# Epoch 135/200
# 21/21 [==============================] - 3s 135ms/step - loss: 0.0079 - accuracy: 0.9940 - val_loss: 1.2788 - val_accuracy: 0.8125
# Epoch 136/200
# 21/21 [==============================] - 3s 133ms/step - loss: 5.6003e-04 - accuracy: 1.0000 - val_loss: 1.1148 - val_accuracy: 0.8125
# Epoch 137/200
# 21/21 [==============================] - 3s 133ms/step - loss: 4.1851e-04 - accuracy: 1.0000 - val_loss: 1.0998 - val_accuracy: 0.8125
# Epoch 138/200
# 21/21 [==============================] - 3s 132ms/step - loss: 2.0443e-04 - accuracy: 1.0000 - val_loss: 1.0985 - val_accuracy: 0.8125
# Epoch 139/200
# 21/21 [==============================] - 3s 134ms/step - loss: 7.2580e-04 - accuracy: 1.0000 - val_loss: 1.0939 - val_accuracy: 0.8125
# Epoch 140/200
# 21/21 [==============================] - 3s 135ms/step - loss: 0.0296 - accuracy: 0.9940 - val_loss: 1.0395 - val_accuracy: 0.8125
# Epoch 141/200
# 21/21 [==============================] - 3s 135ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.9813 - val_accuracy: 0.8125
# Epoch 142/200
# 21/21 [==============================] - 3s 136ms/step - loss: 5.2159e-04 - accuracy: 1.0000 - val_loss: 1.0152 - val_accuracy: 0.8125
# Epoch 143/200
# 21/21 [==============================] - 3s 135ms/step - loss: 2.0331e-04 - accuracy: 1.0000 - val_loss: 1.0465 - val_accuracy: 0.8125
# Epoch 144/200
# 21/21 [==============================] - 3s 133ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.1050 - val_accuracy: 0.8125
# Epoch 145/200
# 21/21 [==============================] - 3s 135ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 1.2305 - val_accuracy: 0.8125
# Epoch 146/200
# 21/21 [==============================] - 3s 132ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss:
ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 1.3545 - val_accuracy: 0.8125
# Epoch 167/200
# 21/21 [==============================] - 3s 134ms/step - loss: 0.0141 - accuracy: 0.9940 - val_loss: 1.4569 - val_accuracy: 0.8125
# Epoch 168/200
# 21/21 [==============================] - 3s 133ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 1.5544 - val_accuracy: 0.8125
# Epoch 169/200
# 21/21 [==============================] - 3s 134ms/step - loss: 5.4246e-04 - accuracy: 1.0000 - val_loss: 1.5715 - val_accuracy: 0.8125
# Epoch 170/200
# 21/21 [==============================] - 3s 134ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.5712 - val_accuracy: 0.8125
# Epoch 171/200
# 21/21 [==============================] - 3s 137ms/step - loss: 0.0262 - accuracy: 0.9940 - val_loss: 1.4411 - val_accuracy: 0.8125
# Epoch 172/200
# 21/21 [==============================] - 3s 137ms/step - loss: 0.0141 - accuracy: 0.9940 - val_loss: 1.3653 - val_accuracy: 0.8125
# Epoch 173/200
# 21/21 [==============================] - 3s 136ms/step - loss: 0.0236 - accuracy: 0.9940 - val_loss: 1.2946 - val_accuracy: 0.8750
# Epoch 174/200
# 21/21 [==============================] - 3s 134ms/step - loss: 0.0217 - accuracy: 0.9940 - val_loss: 1.3477 - val_accuracy: 0.8125
# Epoch 175/200
# 21/21 [==============================] - 3s 134ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 1.5581 - val_accuracy: 0.8750
# Epoch 176/200
# 21/21 [==============================] - 3s 133ms/step - loss: 0.0053 - accuracy: 0.9940 - val_loss: 1.5954 - val_accuracy: 0.8750
# Epoch 177/200
# 21/21 [==============================] - 3s 132ms/step - loss: 0.0553 - accuracy: 0.9880 - val_loss: 1.2867 - val_accuracy: 0.8125
# Epoch 178/200
# 21/21 [==============================] - 3s 133ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.3448 - val_accuracy: 0.8125
# Epoch 179/200
# 21/21 [==============================] - 3s 136ms/step - loss: 0.0401 - accuracy: 0.9880 - val_loss: 1.3091 - val_accuracy: 0.8125
# Epoch 180/200
# 21/21 [==============================] - 3s 138ms/step - loss: 0.0315 - accuracy: 0.9940 - val_loss: 1.3428 - val_accuracy: 0.8125
# Epoch 181/200
# 21/21 [==============================] - 3s 135ms/step - loss: 0.1121 - accuracy: 0.9819 - val_loss: 1.4593 - val_accuracy: 0.8125
# Epoch 182/200
# 21/21 [==============================] - 3s 135ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 1.6626 - val_accuracy: 0.7500
# Epoch 183/200
# 21/21 [==============================] - 3s 134ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 1.8460 - val_accuracy: 0.7500
# Epoch 184/200
# 21/21 [==============================] - 3s 135ms/step - loss: 0.0064 - accuracy: 0.9940 - val_loss: 1.9011 - val_accuracy: 0.7500
# Epoch 185/200
# 21/21 [==============================] - 3s 137ms/step - loss: 0.0137 - accuracy: 0.9940 - val_loss: 1.9318 - val_accuracy: 0.7500
# Epoch 186/200
# 21/21 [==============================] - 3s 138ms/step - loss: 2.4207e-04 - accuracy: 1.0000 - val_loss: 1.9126 - val_accuracy: 0.7500
# Epoch 187/200
# 21/21 [==============================] - 3s 139ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.9570 - val_accuracy: 0.7500
# Epoch 188/200
# 21/21 [==============================] - 3s 138ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 1.9322 - val_accuracy: 0.7500
# Epoch 189/200
# 21/21 [==============================] - 3s 138ms/step - loss: 8.6907e-04 - accuracy: 1.0000 - val_loss: 1.9270 - val_accuracy: 0.7500
# Epoch 190/200
# 21/21 [==============================] - 3s 139ms/step - loss: 0.0160 - accuracy: 0.9940 - val_loss: 1.8913 - val_accuracy: 0.7500
# Epoch 191/200
# 21/21 [==============================] - 3s 138ms/step - loss: 0.0622 - accuracy: 0.9880 - val_loss: 1.9984 - val_accuracy: 0.8125
# Epoch 192/200
# 21/21 [==============================] - 3s 140ms/step - loss: 0.0153 - accuracy: 0.9940 - val_loss: 1.7506 - val_accuracy: 0.8125
# Epoch 193/200
# 21/21 [==============================] - 3s 137ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.7473 - val_accuracy: 0.8125
# Epoch 194/200
# 21/21 [==============================] - 3s 139ms/step - loss: 0.0345 - accuracy: 0.9940 - val_loss: 1.7668 - val_accuracy: 0.8125
# Epoch 195/200
# 21/21 [==============================] - 3s 138ms/step - loss: 2.4729e-04 - accuracy: 1.0000 - val_loss: 1.7854 - val_accuracy: 0.8125
# Epoch 196/200
# 21/21 [==============================] - 3s 135ms/step - loss: 7.9777e-04 - accuracy: 1.0000 - val_loss: 1.7979 - val_accuracy: 0.8125
# Epoch 197/200
# 21/21 [==============================] - 3s 136ms/step - loss: 1.0867e-04 - accuracy: 1.0000 - val_loss: 1.8051 - val_accuracy: 0.8125
# Epoch 198/200
# 21/21 [==============================] - 3s 134ms/step - loss: 1.3755e-04 - accuracy: 1.0000 - val_loss: 1.8081 - val_accuracy: 0.8125
# Epoch 199/200
# 21/21 [==============================] - 3s 139ms/step - loss: 0.0343 - accuracy: 0.9940 - val_loss: 1.8257 - val_accuracy: 0.8125
# Epoch 200/200
# 21/21 [==============================] - 3s 142ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.8761 - val_accuracy: 0.8125

# %%
print("[INFO] evaluating network...")
testGen.reset()
predIdxs = model.predict_generator(testGen,
	steps=(totalTest // config.BS) + 1)
# for each image in the testing set we need to find the index of the
# label with corresponding largest predicted probability
predIdxs = np.argmax(predIdxs, axis=1)
# show a nicely formatted classification report
print(classification_report(testGen.classes, predIdxs,
	target_names=testGen.class_indices.keys()))
# serialize the model to disk
print("[INFO] saving model...")
model.save(config.MODEL_PATH, save_format="h5")
N = config.NUM_EPOCHS
# Out:
# [INFO] evaluating network...
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2001: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
#                precision    recall  f1-score   support
#
#  first_degree       0.69      0.90      0.78        10
#       no_burn       0.94      0.76      0.84        21
# second_degree       1.00      1.00      1.00        12
#  third_degree       0.96      1.00      0.98        22
#
#      accuracy                           0.91        65
#     macro avg       0.90      0.92      0.90        65
#  weighted avg       0.92      0.91      0.91        65
#
# [INFO] saving model...
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %%
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy on Dataset")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
plt.savefig("plot.png")

# %%
H.history
