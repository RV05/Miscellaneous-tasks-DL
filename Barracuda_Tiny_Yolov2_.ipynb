# %% [markdown]
# <a href="https://colab.research.google.com/github/RV05/Miscellaneous-tasks-DL/blob/main/Barracuda_Tiny_Yolov2_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Wed_Jul_22_19:09:09_PDT_2020
# Cuda compilation tools, release 11.0, V11.0.221
# Build cuda_11.0_bu.TC445_37.28845127_0

# %%
cd /content/drive/MyDrive/barracuda/darknet/
# Out:
# /content/drive/MyDrive/barracuda/darknet

# %%
# !make
# !chmod +x ./darknet
# Out:
# gcc -Iinclude/ -Isrc/ -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -DCUDNN  -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘time_gpu’:
# ./src/gemm.c:232:9: warning: ‘cudaThreadSynchronize’ is deprecated [-Wdeprecated-declarations]
#          cudaThreadSynchronize();
#          ^~~~~~~~~~~~~~~~~~~~~
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:11,
#                  from ./src/utils.h:5,
#                  from ./src/gemm.c:2:
# /usr/local/cuda/include/cuda_runtime_api.h:967:57: note: declared here
#  extern __CUDA_DEPRECATED __host__ cudaError_t CUDARTAPI cudaThreadSynchronize(void);
#                                                          ^~~~~~~~~~~~~~~~~~~~~
# ...

# %%
# !rm /content/darknet/backup -r
# !ln -s /content/drive/'My Drive'/YOLOv3_weight/backup /content/drive/MyDrive/barracuda/darknet
# Out:
# rm: cannot remove '/content/darknet/backup': No such file or directory
# ln: failed to create symbolic link '/content/drive/MyDrive/barracuda/darknet/backup': File exists

# %%
# !sudo apt install dos2unix
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   dos2unix
# 0 upgraded, 1 newly installed, 0 to remove and 40 not upgraded.
# Need to get 351 kB of archives.
# After this operation, 1,267 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 dos2unix amd64 7.3.4-3 [351 kB]
# Fetched 351 kB in 1s (673 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package dos2unix.
# ...

# %%
# !dos2unix ./data/train.txt
# !dos2unix ./data/val.txt
# !dos2unix ./data/yolo.data
# !dos2unix ./data/yolo.names
# !dos2unix /content/drive/MyDrive/barracuda/darknet/cfg/yolov2_custom_train_tiny.cfg
# Out:
# dos2unix: converting file ./data/train.txt to Unix format...
# dos2unix: converting file ./data/val.txt to Unix format...
# dos2unix: converting file ./data/yolo.data to Unix format...
# dos2unix: converting file ./data/yolo.names to Unix format...
# dos2unix: converting file /content/drive/MyDrive/barracuda/darknet/cfg/yolov2_custom_train_tiny.cfg to Unix format...

# %%
# If your output cell shows something similar like belows, then congratulation, your model has started training successfully!
# !cd /content/drive/MyDrive/barracuda/darknet
# !./darknet detector train /content/drive/MyDrive/barracuda/darknet/data/yolo.data /content/drive/MyDrive/barracuda/darknet/cfg/yolov2_custom_train_tiny.cfg /content/drive/MyDrive/barracuda/darknet/darknet53.conv.74
# Out:
# Streaming output truncated to the last 5000 lines.
# Region Avg IOU: 0.716826, Class: 1.000000, Obj: 0.438613, No Obj: 0.003526, Avg Recall: 1.000000,  count: 1
# 52274: 8.259350, 6.130712 avg, 0.001000 rate, 0.015497 seconds, 52274 images
# Loaded: 0.013760 seconds
# Region Avg IOU: 0.560620, Class: 1.000000, Obj: 0.906422, No Obj: 0.001714, Avg Recall: 1.000000,  count: 1
# 52275: 0.822004, 5.599841 avg, 0.001000 rate, 0.021892 seconds, 52275 images
# Loaded: 0.012238 seconds
# Region Avg IOU: 0.780124, Class: 1.000000, Obj: 0.554679, No Obj: 0.002864, Avg Recall: 1.000000,  count: 2
# 52276: 22.786461, 7.318503 avg, 0.001000 rate, 0.020376 seconds, 52276 images
# Loaded: 0.019609 seconds
# Region Avg IOU: 0.721082, Class: 1.000000, Obj: 0.926498, No Obj: 0.001731, Avg Recall: 1.000000,  count: 2
# 52277: 0.593176, 6.645970 avg, 0.001000 rate, 0.011791 seconds, 52277 images
# Loaded: 0.022527 seconds
# ...

# %% [markdown]
# ## Train with pre-trained weight.

# %%
# copy pre-trained weight from your Drive to folder darknet
# !cp /content/drive/'My Drive'/YOLOv3_files/yolov3_900.weights /content/darknet

# train annd save loss result in log.txt
# %cd /content/darknet
# !./darknet detector train data/yolo.data cfg/yolov3_custom_train.cfg yolov3_900.weights | tee log.txt

# %% [markdown]
# ## The End!
